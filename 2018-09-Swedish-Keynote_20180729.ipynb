# %% [markdown]
# <font size="6"><b><center>Housing and Heterogeneity: A Narrative and An Agenda</center></b></font>
# <br>
# <font size="5"><b><center>Christopher Carroll</center></b></font>

# %% [markdown]
# # Alternate History: From 1990 we had
#
# Data containing _all_ of:
#    * Integrated HH balance sheets;
#    * Expectations ('What will the stock/housing prices do?')
#    * Actions ('Did you buy stocks/houses?')
#    * Explanations ('Why did you do that?')
#
# Models able to match this heterogeneity
#    * Not just balance sheets
#       * We can get there with conventional heterogeneity
#          * Risk preference, discount rates, income shocks
#    * Need heterogeneity in belief formation
#       * Many competing theories right now
#       * Let's run with one:
#          * _Everybody_ has extrapolative expectations _a la_ Nagel
#          * Shiller looks back 150 years
#          * Some people look back 3 years
#          * "Memory" for short
#
# <!--
#   * Result:
#       * Dot-Com Bubble a Rockefeller moment:
#           * when shoeshine boy is giving stock tips
#
# ## Toy Theory Of Bubbles
#
# Guess: Nagel model with heterogeneous memory
#
# 0. Some genuine good news arrives
#    * Fundamental value of asset is higher
# 0. Spread of beliefs is like a disease
#    * Susceptible
#        * People with funds ...
#        * ... and short lookback period
#        * ... and high risk tolerance
#    * Infected
#        * Shoeshine boy, hairdresser
#    * Recovered
#        * See it in expectations and actions
# 0. Purpose?
#    * Illustrate interplay between theory, data
#    * NOT to claim this is the _right_ theory
#
# ## Prehistory
#
# Mid-90's Productivity Acceleration
#   * Greenspan's "New Economy" Heresy (~1996)
#   * Mark of "Consensus": <!-- Achieved faster than for 1970s slowdown -->
#      * [Economic Report of the President (2001)](http://www.presidency.ucsb.edu/economic_reports/2001.pdf)
# <!--        * "The New Trend In Productivity" (p. 26) -->
#
# Consequences: Boom in asset prices
#   0. Stock Market (1994-2001)
# <!--      * Peaked about when ERP conceded -->
#   0. 30 percent rise in house prices
#
# ## Alternate Prehistory
#
# 0. Identify people with _ex ante_
#       * Low Memory (young; less education)
#       * Lower risk aversion
#       * Surprisingly fast income growth
# 0. _We see_ these people differentially
#       * Had biggest change in expectations
#       * Had biggest change in participation
# 0. _They tell us_ they
#       * "Invested because $\mathbb{E}[\Delta p]$
#       * (cf Hall 2000)
#
# <!-- Blinder:After the Music Stopped -->
#
# <!--
# ## Prehistoric Theories
#
# * Rationally Exuberant Expectations
#    * Hall (2000) AEA Ely Lecture
#       * Companies rapidly creating "intangible capital"
# * Irrational Exuberance (Shiller)
#    * No Usable Theory of the _Right_ model
# -->
#
# -->
#
# <!---
#     * Accounting frauds:
#       * "Off balance sheet" entities (Enron, others)
#       * "Crisis of Confidence" in financial markets -->
# <!--- Find a figure showing data, maybe from Shiller, with expectations of stock returns in some period before and after the crash of the dot-com bubble in 2001 --->
#
# ## History
#
# 2001: China Joins WTO
#    * Chinese external saving unleashed
#    * $\Rightarrow$ Interest rates lowest since Great Depression
# <!--      * Real and nominal -->
# <!--      * Greenspan "conundrum" speech (2004?) -->
# <!--         * "Something funny going on around here" -->
# <!---        * Sidenote: Theory says the "conundrum" was why 30 year rates and overnight rates were so highly correlated _before_ 2004 --->
#       * Bernanke "global savings glut" speech (2005)
#
# ## The Boom
# * 2003
#     * Beginnings of "financial innovation"
# <!--       * In the Volcker sense -->
# * 2004-2007
#     * Large increase in availability of credit
#        * Subprime _and_ prime
#     * Rapid rise in housing prices
# <!-- [Shiller]![figure_03.png](attachment:figure_03.png) -->
#
# ## The Bust
# * 2008
#     * The Panic
# <!---        * Retail Sales Collapse figure -->
# * 2009-2017
#     * Slow recovery from a crisis of confidence (Hall)

# %% [markdown]
# # Alternate History
#
# ## Suppose We'd had:
# Data and Models we should aim to have in 2030
#    * What Good Would It Have Done?
# <!-- Not quite "What if Hitler Had Won?" but thrilling for economists -->
#
#
# ## By 2030: Data
#
#    * _Dynamics_ of household balance sheets
#    * _Combined_ with data on choices
#       * Stock investment, housing purchases
#    * _Combined_ with data on expectations
#    * _Combined_ with data on "trust"
#
#
# ## By 2030: Models
#
# That match measured heterogeneity in
#    * Balance Sheet _Dynamics_
#       * Income, Wealth, Debt, Portfolios
#    * Risk Aversion, Discount Rates
#       * We're getting there
#    * Expectations
#       * Expectations _are data_
#
# ## Alternate Prehistory
#
# _Marginal_ investor during dot com bubble:
#    * Relative newcomers to stock investing
#    * With extrapolative expectations
#       * Matched by Nagel or Shleifer models
# _Marginal_ disinvestor during dot com bust:
#    * Extrapolative expectations
#    * Lost confidence/trust in financial markets
#
# ## Alternate History
#
# _Marginal_ investor:
#    * Stock market is a casino
#    * Housing is "safe as houses"
#
# Exuberant fringe:
#    * John D Rockefeller:
#       * Bubble: Shoeshine boy giving you stock tips
#    * Hal Varian
#       * "My hairdresser was flipping houses"
#
# ## Data _are_ the plural of anecdotes
#    * In the absence of data, unwise to dismiss anecdotes
#
# * Little change in proportion of households planning to buy houses
#         * Figures from Slok
#     * Substantial increase in "speculative" buyers
#         * _Marginal_ buyers are the ones whose expectations matter
#         * From Mian and Sufi (various)
#         * Rockefeller and Varian
#
# ## Alternate Boom
#
# ## Alternate Bust

# %% [markdown]
# # Part 2: Agenda

# %% [markdown]
# # Infrastructure To Prevent A Rerun
#
# ## Improvments Needed in Both Models and Data
#
# ### Two Kinds of Heterogeneity: Circumstances and Beliefs
#
# ### Circumstances: What You CAN Do
#
# ### Beliefs $\Rightarrow$ What You WILL Do
#
# ## Payoffs to this Agenda
#
# ### Macroprudential: Crisis Prevention
#
# ### Cyclical: Prediction, Feedback, and Control

# %% [markdown]
# # Circumstances and Beliefs

# %% [markdown]
# ## Circumstances
# 0. Household Balance Sheets
# 0. Household Shocks
#    * Income
#    * Expenditure
#
# ## Beliefs
# 0. Expectations Surveys
#    * Everybody since Keynes: Expectations are key to Macro
#    * Until early naughts, taboo against using expectations data
#    * Some data collected nonetheless
#    * Still Pretty Woeful
#    * Getting better
# 0. The Next Frontier: _Why_ Do You Believe It?
# 0. Abolish Consumer Expenditure Surveys!
#
# Speculators: Pecuniary externality
